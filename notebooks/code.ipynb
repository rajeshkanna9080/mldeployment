# %%
# !pip install seaborn 
# !pip install matplotlib
# !pip install numpy 
# !pip install pandas

# %%
import seaborn as sns
import numpy as np
import pandas as pd
# Out:
#   Cell In[7], line 3
#     import
#           ^
# SyntaxError: invalid syntax
